# %%
import seaborn as sb

# %%
import pandas as pd
df = pd.read_csv("C:/Users/Sneha/ML_Codons/Datasets/IBM_attrition_.csv")
df
# Out:
#       Age  Attrition          Business../Travel  DailyRate  \
# 0      41          1  Travel_Rarely/Travel_less       1102
# 1      49          0          Travel_Frequently        279
# 2      37          1  Travel_Rarely/Travel_less       1373
# 3      33          0          Travel_Frequently       1392
# 4      27          0  Travel_Rarely/Travel_less        591
# ...   ...        ...                        ...        ...
# 1465   36          0          Travel_Frequently        884
# 1466   39          0  Travel_Rarely/Travel_less        613
# 1467   27          0  Travel_Rarely/Travel_less        155
# 1468   49          0          Travel_Frequently       1023
# 1469   34          0  Travel_Rarely/Travel_less        628
#
#                         Department  DistanceFromHome  Education  \
# 0                            Sales                 1          2
# 1     Research & Development / R&D                 8          1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Business../Travel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'Environment\Satisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'Num\Companies_Worked',
#        'Over18', 'OverTime', 'Percent\Salary\Hike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'Training\..Times_LastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# Business../Travel            object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# Environment\Satisfaction      int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# Num\Companies_Worked          int64
# Over18                       object
# OverTime                     object
# Percent\Salary\Hike           int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# ...

# %%
df.columns.unique()
# Out:
# Index(['Age', 'Attrition', 'BusinessORTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentORSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumOFCompanies_Worked', 'Over18', 'OverTime', 'Percent_Salary_Hike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'Training_lastyear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df=df.rename(columns={"Business../Travel":"BusinessORTravel","Environment\Satisfaction":"EnvironmentORSatisfaction","Num\Companies_Worked":"NumOFCompanies_Worked",
                     "Percent\Salary\Hike":"Percent_Salary_Hike","Training\..Times_LastYear":"Training_lastyear"})

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# BusinessORTravel             object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentORSatisfaction     int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumOFCompanies_Worked         int64
# Over18                       object
# OverTime                     object
# Percent_Salary_Hike           int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessORTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentORSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumOFCompanies_Worked', 'Over18', 'OverTime', 'Percent_Salary_Hike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'Training_lastyear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# BusinessORTravel             0
# DailyRate                    0
# Department                   0
# DistanceFromHome             0
# Education                    0
# EducationField               0
# EmployeeCount                0
# EmployeeNumber               0
# EnvironmentORSatisfaction    0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                     0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# NumOFCompanies_Worked        0
# Over18                       0
# OverTime                     0
# Percent_Salary_Hike          0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# Training_lastyear            0
# ...

# %%
df
# Out:
#       Age  Attrition           BusinessORTravel  DailyRate  \
# 0      41          1  Travel_Rarely/Travel_less       1102
# 1      49          0          Travel_Frequently        279
# 2      37          1  Travel_Rarely/Travel_less       1373
# 3      33          0          Travel_Frequently       1392
# 4      27          0  Travel_Rarely/Travel_less        591
# ...   ...        ...                        ...        ...
# 1465   36          0          Travel_Frequently        884
# 1466   39          0  Travel_Rarely/Travel_less        613
# 1467   27          0  Travel_Rarely/Travel_less        155
# 1468   49          0          Travel_Frequently       1023
# 1469   34          0  Travel_Rarely/Travel_less        628
#
#                         Department  DistanceFromHome  Education  \
# 0                            Sales                 1          2
# 1     Research & Development / R&D                 8          1
# ...

# %%
df.Gender.value_counts()
df.Age.value_counts()
df.Gender.value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df.Age.value_counts()
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 28    48
# 27    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 48    19
# 51    19
# 53    19
# 54    18
# 52    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
df.Department .value_counts()
# Out:
# Department
# Research & Development / R&D    961
# Sales                           446
# Human Resources / HR             63
# Name: count, dtype: int64

# %%
df.BusinessORTravel.value_counts()
# Out:
# BusinessORTravel
# Travel_Rarely/Travel_less    1043
# Travel_Frequently             277
# Non-Travel                    150
# Name: count, dtype: int64

# %%
df.Department.value_counts()
# Out:
# Department
# Research & Development / R&D    961
# Sales                           446
# Human Resources / HR             63
# Name: count, dtype: int64

# %%
df.EducationField .value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# BusinessORTravel             object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentORSatisfaction     int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumOFCompanies_Worked         int64
# Over18                       object
# OverTime                     object
# Percent_Salary_Hike           int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# ...

# %%
df.JobRole.value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
df.OverTime.value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
df.Over18.value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
sb.countplot(df.Gender)
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sb.countplot(df.Age)
# Out:
# <Axes: ylabel='count'>

# %%
sb.countplot(df.Department)
# Out:
# <Axes: xlabel='count', ylabel='Department'>

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentORSatisfaction   HourlyRate  \
# count         1470.0     1470.000000                1470.000000  1470.000000
# mean             1.0     1024.865306                   2.721769    65.891156
# ...

# %%
df.groupby("Department")["Attrition"].mean()
# Out:
# Department
# Human Resources / HR            0.190476
# Research & Development / R&D    0.138398
# Sales                           0.206278
# Name: Attrition, dtype: float64

# %%
df.groupby("JobRole")["Attrition"].mean()
# Out:
# JobRole
# Healthcare Representative    0.068702
# Human Resources              0.230769
# Laboratory Technician        0.239382
# Manager                      0.049020
# Manufacturing Director       0.068966
# Research Director            0.025000
# Research Scientist           0.160959
# Sales Executive              0.174847
# Sales Representative         0.397590
# Name: Attrition, dtype: float64

# %%
df.groupby("Gender")["Attrition"].mean()
# Out:
# Gender
# Female    0.147959
# Male      0.170068
# Name: Attrition, dtype: float64

# %%
df.groupby("OverTime")["Attrition"].mean()
# Out:
# OverTime
# No     0.104364
# Yes    0.305288
# Name: Attrition, dtype: float64

# %%
pd.pivot_table(df,index="Department",columns="JobRole",values="Attrition",margins=True)
# Out:
# JobRole                       Healthcare Representative  Human Resources  \
# Department
# Human Resources / HR                                NaN         0.230769
# Research & Development / R&D                   0.068702              NaN
# Sales                                               NaN              NaN
# All                                            0.068702         0.230769
#
# JobRole                       Laboratory Technician   Manager  \
# Department
# Human Resources / HR                            NaN  0.000000
# Research & Development / R&D               0.239382  0.055556
# Sales                                           NaN  0.054054
# All                                        0.239382  0.049020
#
# JobRole                       Manufacturing Director  Research Director  \
# Department
# Human Resources / HR                             NaN                NaN
# Research & Development / R&D                0.068966              0.025
# ...

# %%
pd.pivot_table(df,index="OverTime",columns="JobRole",values="Attrition",margins=True)
# Out:
# JobRole   Healthcare Representative  Human Resources  Laboratory Technician  \
# OverTime
# No                         0.074468         0.179487               0.157360
# Yes                        0.054054         0.384615               0.500000
# All                        0.068702         0.230769               0.239382
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# OverTime
# No        0.013333                0.056604           0.017544
# Yes       0.148148                0.102564           0.043478
# All       0.049020                0.068966           0.025000
#
# JobRole   Research Scientist  Sales Executive  Sales Representative       All
# OverTime
# No                  0.071795         0.112069              0.288136  0.104364
# Yes                 0.340206         0.329787              0.666667  0.305288
# All                 0.160959         0.174847              0.397590  0.161224

# %%
pd.pivot_table(df,index="Gender",columns="JobRole",values="Attrition",margins=True)
# Out:
# JobRole  Healthcare Representative  Human Resources  Laboratory Technician  \
# Gender
# Female                    0.098039         0.375000               0.188235
# Male                      0.050000         0.166667               0.264368
# All                       0.068702         0.230769               0.239382
#
# JobRole   Manager  Manufacturing Director  Research Director  \
# Gender
# Female   0.042553                0.055556           0.030303
# Male     0.054545                0.082192           0.021277
# All      0.049020                0.068966           0.025000
#
# JobRole  Research Scientist  Sales Executive  Sales Representative       All
# Gender
# Female             0.149123         0.151515              0.421053  0.147959
# Male               0.168539         0.190722              0.377778  0.170068
# All                0.160959         0.174847              0.397590  0.161224
